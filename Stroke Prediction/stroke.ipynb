# %%
import pandas as pd
import sklearn
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv('/content/drive/MyDrive/Machine Learning/data/Stroke Train.csv')

# %%
df
# Out:
#           id  gender   age  hypertension  heart_disease ever_married  \
# 0          0    Male  28.0             0              0          Yes
# 1          1    Male  33.0             0              0          Yes
# 2          2  Female  42.0             0              0          Yes
# 3          3    Male  56.0             0              0          Yes
# 4          4  Female  24.0             0              0           No
# ...      ...     ...   ...           ...            ...          ...
# 15299  15299  Female  22.0             0              0           No
# 15300  15300  Female  46.0             1              0          Yes
# 15301  15301  Female  75.0             0              0          Yes
# 15302  15302    Male  46.0             0              0          Yes
# 15303  15303  Female  14.0             0              0           No
#
#            work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %%
df.isna().sum()
# Out:
# id                   0
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# dtype: int64

# %%
df1 = df

# %% [markdown]
# #Predict

# %%
logreg = LogisticRegression(solver = 'liblinear', random_state = 1)

# %%
y = df['stroke']

# %%
cols = ['age', 'hypertension', 'heart_disease', 'bmi', 'avg_glucose_level', 'gender']

# %%
X = df[cols]

# %%
Xdf1 = df1[cols]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
ohe = OneHotEncoder()

# %%
ohe.fit_transform(df[['Embarked']])

# %%
ct = make_column_transformer((ohe, ['gender']), remainder = 'passthrough')

# %%
pipe = make_pipeline(ct, logreg)

# %%
pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(),
#                                                   ['gender'])])),
#                 ('logisticregression',
#                  LogisticRegression(random_state=1, solver='liblinear'))])

# %%
y_pred = pipe.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy * 100:.8f}%')
# Out:
# Accuracy: 95.85102908%

# %% [markdown]
# Accuracy: 95.85102908%

# %% [markdown]
# #Kaggle

# %%
dftest = pd.read_csv('/content/drive/MyDrive/Machine Learning/data/Stroke Test.csv')

# %%
dftest.shape
# Out:
# (10204, 11)

# %%
X_testk = dftest[cols]

# %%
ct = make_column_transformer((ohe, ['gender']), remainder = 'passthrough')

# %%
y_predk = pipe.predict(X_testk)

# %%
kaggle = pd.DataFrame()

# %%
kaggle['stroke'] = y_predk

# %%
kaggle['id'] = dftest['id']

# %%
kaggle
# Out:
#        stroke     id
# 0           0  15304
# 1           0  15305
# 2           0  15306
# 3           0  15307
# 4           0  15308
# ...       ...    ...
# 10199       0  25503
# 10200       0  25504
# 10201       0  25505
# 10202       0  25506
# 10203       0  25507
#
# [10204 rows x 2 columns]

# %%
kaggle.set_index('id', inplace = True)

# %%
kaggle
# Out:
#        stroke
# id
# 15304       0
# 15305       0
# 15306       0
# 15307       0
# 15308       0
# ...       ...
# 25503       0
# 25504       0
# 25505       0
# 25506       0
# 25507       0
#
# [10204 rows x 1 columns]

# %%
kaggle.to_csv('/content/drive/MyDrive/Machine Learning/submissions/stroke submission.csv')
